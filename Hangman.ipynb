# %%
pip install random-word

# %%
import random
from random_word import RandomWords

print('Time To Play Hangman!')
r = RandomWords()
word_list= r.get_random_words()
secret = random.choice(word_list)
guesses = ''
already_guessed = []

turns = 5

while turns > 0:
  missed = 0

  for letter in secret:
    if letter in guesses:
      print(letter)
    else:
      print('_')
      missed += 1

  if missed == 0:
    print('You win!')
    print('The answer is:', secret)
    break

  guess = input('guess a letter: ')
  guesses += guess
  already_guessed.extend([guess])
  print('Already guesses: ' ,already_guessed)  
    
  if len(guess) !=1:
            print("!!Pick One Letter At Same Time!!")
        
  elif guess not in 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwyz- ':
            print("!!Please Only Pick Letters!!")   

  elif guess not in secret:
    turns -= 1
    print('Nope!')
    print('You have', turns , 'more turns')
    if turns == 5:   
        print("________      ")
        print("|      |      ")
        print("|             ")
        print("|             ")
        print("|             ")
        print("|             ")
    if turns == 4: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|             ")
        print("|             ")
        print("|             ")
    if turns == 3: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|      ")
        print("|             ")
        print("|             ")
    if turns == 2: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|             ")
        print("|             ")
    if turns == 1: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|     /       ")
        print("|             ")
    if turns == 0:
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|     / \     ")
        print("|             ")
        print('The answer is:', secret)
# Out:
# Time To Play Hangman!
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# guess a letter: w
# Already guesses:  ['w']
# Nope!
# You have 4 more turns
# ________
# |      |
# |      0
# |
# |
# |
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# guess a letter: a
# Already guesses:  ['w', 'a']
# _
# _
# _
# _
# _
# _
# _
# a
# _
# _
# _
# _
# _
# _
# _
# guess a letter: e
# Already guesses:  ['w', 'a', 'e']
# _
# _
# _
# e
# _
# _
# _
# a
# _
# _
# e
# _
# _
# _
# _
# guess a letter: b
# Already guesses:  ['w', 'a', 'e', 'b']
# Nope!
# You have 3 more turns
# ________
# |      |
# |      0
# |     /|
# |
# |
# _
# _
# _
# e
# _
# _
# _
# a
# _
# _
# e
# _
# _
# _
# _
# guess a letter: n
# Already guesses:  ['w', 'a', 'e', 'b', 'n']
# _
# _
# _
# e
# _
# _
# _
# a
# n
# _
# e
# _
# _
# _
# _
# guess a letter: 4
# Already guesses:  ['w', 'a', 'e', 'b', 'n', '4']
# Please Only Pick Letters!
# _
# _
# _
# e
# _
# _
# _
# a
# n
# _
# e
# _
# _
# _
# _
# guess a letter: y
# Already guesses:  ['w', 'a', 'e', 'b', 'n', '4', 'y']
# Nope!
# You have 2 more turns
# ________
# |      |
# |      0
# |     /|\
# |
# |
# _
# _
# _
# e
# _
# _
# _
# a
# n
# _
# e
# _
# _
# _
# _
# guess a letter: r
# Already guesses:  ['w', 'a', 'e', 'b', 'n', '4', 'y', 'r']
# _
# _
# _
# e
# _
# _
# _
# a
# n
# _
# e
# _
# _
# _
# r
# guess a letter: u
# Already guesses:  ['w', 'a', 'e', 'b', 'n', '4', 'y', 'r', 'u']
# Nope!
# You have 1 more turns
# ________
# |      |
# |      0
# |     /|\
# |     /
# |
# _
# _
# _
# e
# _
# _
# _
# a
# n
# _
# e
# _
# _
# _
# r
# guess a letter: s
# Already guesses:  ['w', 'a', 'e', 'b', 'n', '4', 'y', 'r', 'u', 's']
# Nope!
# You have 0 more turns
# ________
# |      |
# |      0
# |     /|\
# |     / \
# |
# The answer is: vice-chancellor

# %%
s

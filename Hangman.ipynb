# %%
import random


print('Time To Play Hangman!')
word_list="computer mechanic apple engineer couch habanero pepper walking dead oak dog nut nuts peanut dayman horse basketball tree barn chicken television phone chair table cat".split()
secret = random.choice(word_list)
guesses = ''
already_guessed = []

turns = 5

while turns > 0:
  missed = 0

  for letter in secret:
    if letter in guesses:
      print(letter)
    else:
      print('_')
      missed += 1

  if missed == 0:
    print('You win!')
    print('The answer is:', secret)
    break

  guess = input('guess a letter: ')
  guesses += guess
  already_guessed.extend([guess])
  print('Already guesses: ' ,already_guessed)  
    
  if len(guess) !=1:
            print("Pick One Letter At Same Time!")
        
  elif guess not in 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwyz ':
            print("Please Only Pick Letters!")   

  elif guess not in secret:
    turns -= 1
    print('Nope!')
    print('You have', turns , 'more turns')
    if turns == 5:   
        print("________      ")
        print("|      |      ")
        print("|             ")
        print("|             ")
        print("|             ")
        print("|             ")
    if turns == 4: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|             ")
        print("|             ")
        print("|             ")
    if turns == 3: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|      ")
        print("|             ")
        print("|             ")
    if turns == 2: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|             ")
        print("|             ")
    if turns == 1: 
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|     /       ")
        print("|             ")
    if turns == 0:
        print("________      ")
        print("|      |      ")
        print("|      0      ")
        print("|     /|\     ")
        print("|     / \     ")
        print("|             ")
        print('The answer is:', secret)
# Out:
# Time To Play Hangman!
# _
# _
# _
# _
# _
# _
# guess a letter: s
# Already guesses:  ['s']
# Nope!
# You have 4 more turns
# ________
# |      |
# |      0
# |
# |
# |
# _
# _
# _
# _
# _
# _
# guess a letter: b
# Already guesses:  ['s', 'b']
# Nope!
# You have 3 more turns
# ________
# |      |
# |      0
# |     /|
# |
# |
# _
# _
# _
# _
# _
# _
# guess a letter: a
# Already guesses:  ['s', 'b', 'a']
# _
# _
# a
# _
# _
# _
# guess a letter: n
# Already guesses:  ['s', 'b', 'a', 'n']
# _
# _
# a
# n
# _
# _
# guess a letter: 4
# Already guesses:  ['s', 'b', 'a', 'n', '4']
# Please Only Pick Letters!
# _
# _
# a
# n
# _
# _
# guess a letter: p
# Already guesses:  ['s', 'b', 'a', 'n', '4', 'p']
# p
# _
# a
# n
# _
# _
# guess a letter: d
# Already guesses:  ['s', 'b', 'a', 'n', '4', 'p', 'd']
# Nope!
# You have 2 more turns
# ________
# |      |
# |      0
# |     /|\
# |
# |
# p
# _
# a
# n
# _
# _
# guess a letter: v
# Already guesses:  ['s', 'b', 'a', 'n', '4', 'p', 'd', 'v']
# ...

# %%
s
